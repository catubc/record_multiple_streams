# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load(r'E:\july_8\audiorec_10sec.npy')
print (data.shape)
# Out:
# (5, 2500000)

# %%
start = 0*250000
end = 10*250000
t = (np.arange(data[0].shape[0])/250000)[start:end]
for k in range(5):
    ax=plt.subplot(2,3,k+1)
    plt.plot(t, data[k,start:end])
    
#plt.ylim(0,6)
plt.show()
